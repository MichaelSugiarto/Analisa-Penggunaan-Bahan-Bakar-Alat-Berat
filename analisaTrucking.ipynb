# %%
import pandas as pd
import numpy as np
import warnings
import re

warnings.filterwarnings('ignore')

# ==============================================================================
# KONFIGURASI FILE
# ==============================================================================
FILE_BBM = "BBM AAB.xlsx"
FILE_HAULAGE = "HAULAGE OKT-DES 2025 (Copy).xlsx"
FILE_DOORING_REVISI = "DOORING_WITH_DISTANCE_REVISI.xlsx" 
OUTPUT_FILE = "HASIL_ANALISA_TRUCKING_AUDIT.xlsx"

# ==============================================================================
# 1. FUNGSI BANTUAN
# ==============================================================================
def clean_unit_name(name):
    """Membersihkan nama unit"""
    if pd.isna(name): return ""
    name = str(name).upper().strip()
    return re.sub(r'[^A-Z0-9]', '', name)

def extract_lambung_code(raw_kpi):
    """Ekstrak kode lambung dari string 'TRAILER - (S35)' -> 'S35'"""
    s = str(raw_kpi).upper().strip()
    match = re.search(r'\((.*?)\)', s)
    if match: return match.group(1).strip()
    parts = s.split()
    if len(parts) > 1:
        last_part = parts[-1]
        if len(last_part) < 6: return last_part
    return s.replace("-", "").strip()

# ==============================================================================
# 2. MEMBACA BBM (SUMBER MAPPING & DATA LITER)
# ==============================================================================
print("1. Membaca BBM AAB.xlsx...")

lambung_to_unit_map = {} 
all_bbm_data = []

try:
    xls_bbm = pd.ExcelFile(FILE_BBM)
    target_sheets = [s for s in xls_bbm.sheet_names if any(x in s.upper() for x in ['OKT', 'NOV'])]
    
    for sheet_name in target_sheets:
        df_head = pd.read_excel(xls_bbm, sheet_name=sheet_name, header=None, nrows=20)
        
        row_liter_idx = None
        for idx, row in df_head.iterrows():
            if row.astype(str).str.contains('LITER', case=False).any():
                row_liter_idx = idx
                break
        
        if row_liter_idx is not None:
            df_full = pd.read_excel(xls_bbm, sheet_name=sheet_name, header=None)
            
            # Deteksi Baris Metadata
            meta_rows = df_full.iloc[:row_liter_idx]
            row_equip_idx = None
            for idx in range(row_liter_idx):
                row_vals = meta_rows.iloc[idx].astype(str).str.upper()
                if row_vals.str.contains('TRAILER').any() or row_vals.str.contains('TRUCK').any():
                    row_equip_idx = idx
                    break
            
            row_kpi_idx = None
            for idx in range(row_liter_idx):
                if idx == row_equip_idx: continue
                if meta_rows.iloc[idx].astype(str).str.contains(r'\(|\)|-|T\d+|S\d+', regex=True).any():
                    row_kpi_idx = idx
                    break
            
            if row_equip_idx is None: row_equip_idx = row_liter_idx - 1
            if row_kpi_idx is None: row_kpi_idx = 0
            
            headers = df_full.iloc[row_liter_idx]
            data_rows = df_full.iloc[row_liter_idx+1:]
            
            row_equip_vals = df_full.iloc[row_equip_idx].ffill() 
            row_kpi_vals = df_full.iloc[row_kpi_idx].ffill()
            
            for col in range(df_full.shape[1]):
                header_str = str(headers.iloc[col]).strip().upper()
                if header_str == 'LITER':
                    equip_name = str(row_equip_vals.iloc[col]).strip().upper()
                    raw_kpi = str(row_kpi_vals.iloc[col]).strip().upper()
                    lambung = extract_lambung_code(raw_kpi)
                    
                    if "TOTAL" in equip_name or "UNNAMED" in equip_name or equip_name == "NAN": continue
                    
                    # Simpan Mapping
                    if lambung and lambung != "NAN":
                        lambung_to_unit_map[lambung] = equip_name
                        lambung_to_unit_map[equip_name] = equip_name # Self-map
                        
                    vals = pd.to_numeric(data_rows.iloc[:, col], errors='coerce').sum()
                    if vals > 0:
                        all_bbm_data.append({'EQUIP NAME': equip_name, 'LITER': vals})

    if all_bbm_data:
        df_bbm_total = pd.DataFrame(all_bbm_data).groupby('EQUIP NAME')['LITER'].sum().reset_index()
        df_bbm_total['Unit_Clean'] = df_bbm_total['EQUIP NAME'].apply(clean_unit_name)
        print(f"   -> Mapping Unit Tersedia: {len(lambung_to_unit_map)}")
    else:
        df_bbm_total = pd.DataFrame(columns=['EQUIP NAME', 'LITER', 'Unit_Clean'])

except Exception as e:
    print(f"   [ERROR] Gagal baca BBM: {e}")
    df_bbm_total = pd.DataFrame(columns=['EQUIP NAME', 'LITER', 'Unit_Clean'])
# Out:
# 1. Membaca BBM AAB.xlsx...
#    -> Mapping Unit Tersedia: 417

# %%
# ==============================================================================
# 5. MERGE AUDIT, TREN BULANAN & REPORTING
# ==============================================================================
print("\n4. Menyusun Laporan Audit & Tren Bulanan...")

# --- 1. PROSES BBM BULANAN (OKT & NOV) ---
monthly_bbm_list = []
try:
    xls_bbm = pd.ExcelFile(FILE_BBM)
    sheet_map = {'OKT': 'Oktober', 'NOV': 'November'}
    for sn in xls_bbm.sheet_names:
        found_m = next((m_std for k, m_std in sheet_map.items() if k in sn.upper()), None)
        if found_m:
            # Baca header liter
            df_h = pd.read_excel(xls_bbm, sheet_name=sn, header=None, nrows=20)
            lit_idx = df_h[df_h.astype(str).apply(lambda x: x.str.contains('LITER', case=False)).any(axis=1)].index
            if len(lit_idx) > 0:
                idx = lit_idx[0]
                df_f = pd.read_excel(xls_bbm, sheet_name=sn, header=None)
                row_eq = df_f.iloc[idx-1].ffill() # Baris nama unit
                for col in range(df_f.shape[1]):
                    if str(df_f.iloc[idx, col]).strip().upper() == 'LITER':
                        raw_n = str(row_eq.iloc[col]).strip().upper()
                        if "TOTAL" in raw_n or "NAN" in raw_n: continue
                        u_clean = clean_unit_name(extract_lambung_code(raw_n))
                        val = pd.to_numeric(df_f.iloc[idx+1:, col], errors='coerce').sum()
                        if val > 0:
                            monthly_bbm_list.append({'Unit_Clean': u_clean, 'Bulan': found_m, 'LITER': val})
except Exception as e: print(f"Error BBM Bulanan: {e}")

df_bbm_monthly = pd.DataFrame(monthly_bbm_list)
if df_bbm_monthly.empty: df_bbm_monthly = pd.DataFrame(columns=['Unit_Clean', 'Bulan', 'LITER'])
else: df_bbm_monthly = df_bbm_monthly.groupby(['Unit_Clean', 'Bulan']).sum().reset_index()

# --- 2. GABUNG OPERASIONAL (Agregat & Bulanan) ---
# Agregat Total
df_ops = pd.merge(df_haulage_valid, df_dooring_valid, on='Unit_Clean', how='outer').fillna(0)
df_ops['Total_Km'] = df_ops['Km_Haulage'] + df_ops['Km_Dooring']
df_ops['Total_TonKm'] = df_ops['TonKm_Haulage'] + df_ops['TonKm_Dooring']
df_ops['Total_Ton'] = df_ops['Ton_Haulage'] + df_ops['Ton_Dooring']

# Bulanan (Tren)
df_door_m = df_dooring.groupby(['Unit_Clean', 'Bulan']).agg({'Ton_Dooring':'sum','TonKm_Dooring':'sum','Jarak_PP_Km':'sum'}).reset_index().rename(columns={'Jarak_PP_Km':'Km_Dooring'})
df_haul_m = df_haulage.groupby(['Unit_Clean', 'Bulan']).agg({'Berat_Ton':'sum','TonKm':'sum','Jarak_Km':'sum'}).reset_index().rename(columns={'Jarak_Km':'Km_Haulage','Berat_Ton':'Ton_Haulage','TonKm':'TonKm_Haulage'})

# --- 3. MERGE FINAL TREN BULANAN ---
df_monthly_merged = pd.merge(df_bbm_monthly, df_door_m, on=['Unit_Clean', 'Bulan'], how='outer').fillna(0)
df_monthly_merged = pd.merge(df_monthly_merged, df_haul_m, on=['Unit_Clean', 'Bulan'], how='outer').fillna(0)

# Restore Nama & Hitung Rasio Bulanan
clean_to_orig = dict(zip(df_bbm_total['Unit_Clean'], df_bbm_total['EQUIP NAME']))
df_monthly_merged['Nama_Unit'] = df_monthly_merged['Unit_Clean'].map(clean_to_orig).fillna(df_monthly_merged['Unit_Clean'])
df_monthly_merged['Total_Ton'] = df_monthly_merged['Ton_Haulage'] + df_monthly_merged['Ton_Dooring']
df_monthly_merged['Total_TonKm'] = df_monthly_merged['TonKm_Haulage'] + df_monthly_merged['TonKm_Dooring']
df_monthly_merged['Total_Km'] = df_monthly_merged['Km_Haulage'] + df_monthly_merged['Km_Dooring']
df_monthly_merged['Fuel_Ratio'] = np.where(df_monthly_merged['Total_TonKm'] > 0, df_monthly_merged['LITER'] / df_monthly_merged['Total_TonKm'], 0)

df_monthly_out = df_monthly_merged[['Nama_Unit', 'Bulan', 'LITER', 'Total_Ton', 'Total_TonKm', 'Fuel_Ratio', 'Total_Km']].sort_values(['Nama_Unit', 'Bulan'])

# --- 4. DATA AUDIT AGREGAT ---
df_audit = pd.merge(df_ops, df_bbm_total, on='Unit_Clean', how='outer', indicator=True)
for c in ['Km_Haulage', 'Ton_Haulage', 'TonKm_Haulage', 'Km_Dooring', 'Ton_Dooring', 'TonKm_Dooring', 'Total_Km', 'Total_Ton', 'Total_TonKm', 'LITER']:
    if c in df_audit.columns: df_audit[c] = df_audit[c].fillna(0)
df_audit['Nama_Unit'] = df_audit['Unit_Clean'].map(clean_to_orig).fillna(df_audit['Unit_Clean'])

df_sukses = df_audit[df_audit['_merge'] == 'both'].copy()
df_sukses['L_per_TonKm'] = np.where(df_sukses['Total_TonKm'] > 0, df_sukses['LITER'] / df_sukses['Total_TonKm'], 0)
df_sukses['Km_per_L'] = np.where(df_sukses['LITER'] > 0, df_sukses['Total_Km'] / df_sukses['LITER'], 0)

df_no_bbm = df_audit[df_audit['_merge'] == 'left_only'].copy()
df_idle = df_audit[df_audit['_merge'] == 'right_only'].copy()
df_unmapped = pd.DataFrame({'Kode_Lambung': list(set(unmapped_dooring + unmapped_haulage)), 'Keterangan': "Gagal Mapping"})

# --- 5. PIVOT TREN ---
df_pivot = df_monthly_out.pivot_table(index='Nama_Unit', columns='Bulan', values='Fuel_Ratio').reset_index().fillna(0)
if 'Oktober' in df_pivot.columns and 'November' in df_pivot.columns:
    df_pivot['Status_Tren'] = df_pivot.apply(lambda x: "MEMBAIK" if 0 < x['November'] < x['Oktober'] else ("MEMBURUK" if x['November'] > x['Oktober'] > 0 else "STABIL"), axis=1)

# ==============================================================================
# 6. EXPORT EXCEL FINAL
# ==============================================================================
with pd.ExcelWriter(OUTPUT_FILE) as writer:
    df_sukses[['Nama_Unit','Total_Km','Total_Ton','Total_TonKm','LITER','L_per_TonKm','Km_per_L']].to_excel(writer, sheet_name='HASIL_ANALISA', index=False)
    df_monthly_out.to_excel(writer, sheet_name='Data_Bulanan', index=False)
    df_pivot.to_excel(writer, sheet_name='Laporan_Tren', index=False)
    df_no_bbm[['Nama_Unit','Total_Km','Total_Ton','Total_TonKm']].to_excel(writer, sheet_name='OPS_TANPA_BBM', index=False)
    df_idle[['Nama_Unit','LITER']].to_excel(writer, sheet_name='BBM_TANPA_OPS', index=False)
    df_unmapped.to_excel(writer, sheet_name='GAGAL_MAPPING', index=False)

print(f"\nSELESAI! File disimpan: {OUTPUT_FILE}")
# Out:
# 4. Menyusun Laporan Audit & Tren Bulanan...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 43
#      40 df_ops['Total_Ton'] = df_ops['Ton_Haulage'] + df_ops['Ton_Dooring']
#      42 # Bulanan (Tren)
# ---> 43 df_door_m = df_dooring.groupby(['Unit_Clean', 'Bulan']).agg({'Ton_Dooring':'sum','TonKm_Dooring':'sum','Jarak_PP_Km':'sum'}).reset_index().rename(columns={'Jarak_PP_Km':'Km_Dooring'})
#      44 df_haul_m = df_haulage.groupby(['Unit_Clean', 'Bulan']).agg({'Berat_Ton':'sum','TonKm':'sum','Jarak_Km':'sum'}).reset_index().rename(columns={'Jarak_Km':'Km_Haulage','Berat_Ton':'Ton_Haulage','TonKm':'TonKm_Haulage'})
#      46 # --- 3. MERGE FINAL TREN BULANAN ---
#
# File e:\anaconda3\envs\spark\Lib\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
# ...

# %%
# ==============================================================================
# 5. MERGE AUDIT, TREND ANALYSIS & REPORTING (FIXED: FORCE MATCHING)
# ==============================================================================
print("\n4. Menyusun Laporan Audit & Tren Bulanan...")

# --- 1. SIAPKAN DATA AGREGAT (SUMBER KEBENARAN) ---
# Kita gabungkan dulu data operasional total untuk mendapatkan daftar unit yang valid
if 'Unit_Clean' not in df_haulage_valid.columns: df_haulage_valid = df_haulage_valid.reset_index()
if 'Unit_Clean' not in df_dooring_valid.columns: df_dooring_valid = df_dooring_valid.reset_index()

df_ops = pd.merge(df_haulage_valid, df_dooring_valid, on='Unit_Clean', how='outer').fillna(0)
df_ops['Total_Km'] = df_ops['Km_Haulage'] + df_ops['Km_Dooring']
df_ops['Total_TonKm'] = df_ops['TonKm_Haulage'] + df_ops['TonKm_Dooring']
df_ops['Total_Ton'] = df_ops['Ton_Haulage'] + df_ops['Ton_Dooring']

# Restore Name Dictionary (Kamus Nama Asli)
clean_to_orig = {}
if not df_bbm_total.empty:
    clean_to_orig = dict(zip(df_bbm_total['Unit_Clean'], df_bbm_total['EQUIP NAME']))

# Gabung dengan BBM Total untuk Audit
df_audit = pd.merge(df_ops, df_bbm_total, on='Unit_Clean', how='outer', indicator=True)

# Isi 0 pada kolom numerik
cols_num = ['Km_Haulage', 'Ton_Haulage', 'TonKm_Haulage', 'Km_Dooring', 'Ton_Dooring', 'TonKm_Dooring', 
            'Total_Km', 'Total_Ton', 'Total_TonKm', 'LITER']
for c in cols_num:
    if c in df_audit.columns: df_audit[c] = df_audit[c].fillna(0)

# Restore Nama Unit
df_audit['Nama_Unit'] = df_audit['Unit_Clean'].map(clean_to_orig).fillna(df_audit['Unit_Clean'])

# --- 2. BUAT "WHITELIST" UNIT VALID ---
# Ini adalah daftar unit yang SUDAH TERBUKTI ada datanya (baik Ops maupun BBM).
# Kita akan gunakan daftar ini untuk memfilter data bulanan.
df_sukses = df_audit[df_audit['_merge'] == 'both'].copy()
df_sukses['L_per_TonKm'] = np.where(df_sukses['Total_TonKm'] > 0, df_sukses['LITER'] / df_sukses['Total_TonKm'], 0)
df_sukses['Km_per_L'] = np.where(df_sukses['LITER'] > 0, df_sukses['Total_Km'] / df_sukses['LITER'], 0)

# DAFTAR KUNCI: Hanya unit ini yang akan kita ambil datanya di sheet OKT/NOV
VALID_UNIT_IDS = set(df_sukses['Unit_Clean'].unique())
print(f"   -> Whitelist Unit Valid: {len(VALID_UNIT_IDS)} Unit (Akan dicari di sheet bulanan)")

# --- 3. DATA AUDIT LAINNYA ---
df_no_bbm = df_audit[df_audit['_merge'] == 'left_only'].copy()
df_no_bbm['Keterangan'] = "Ada Kegiatan Dooring/Haulage, Tapi Data BBM Tidak Ditemukan"
df_idle = df_audit[df_audit['_merge'] == 'right_only'].copy()
df_idle['Keterangan'] = "Ada Pengisian BBM, Tapi Tidak Ada Kegiatan Dooring/Haulage (Unit Idle/Rusak/Lainnya)"
df_unmapped = pd.DataFrame({
    'Kode_Lambung': list(set(unmapped_dooring + unmapped_haulage)),
    'Keterangan': "Kode Lambung ini ada di file kegiatan tapi TIDAK DITEMUKAN di file BBM"
})

# ==============================================================================
# 5.1. ANALISA TREN BULANAN (REVISI TOTAL: PEMBACAAN BBM)
# ==============================================================================
print("   -> Menghitung Tren Efisiensi Bulanan...")
monthly_data = []

# --- A. BBM BULANAN (BACA SHEET OKT & NOV) ---
try:
    xls_bbm = pd.ExcelFile(FILE_BBM)
    # Mapping nama sheet yang mungkin muncul
    sheet_map = {'OKT': 'Oktober', 'NOV': 'November'}
    
    for sheet_name in xls_bbm.sheet_names:
        # Cek apakah nama sheet mengandung OKT atau NOV
        bulan_key = next((k for k in sheet_map if k in sheet_name.upper()), None)
        
        if bulan_key:
            bulan_lbl = sheet_map[bulan_key]
            # print(f"      ...Membaca sheet: {sheet_name} ({bulan_lbl})")
            
            # Baca header untuk mencari baris 'LITER'
            df_head = pd.read_excel(xls_bbm, sheet_name=sheet_name, header=None, nrows=20)
            lit_rows = df_head[df_head.astype(str).apply(lambda x: x.str.contains('LITER', case=False)).any(axis=1)].index
            
            if len(lit_rows) > 0:
                idx = lit_rows[0] # Baris dimana kata 'LITER' ditemukan
                df_full = pd.read_excel(xls_bbm, sheet_name=sheet_name, header=None)
                
                # Cari baris Nama Unit (Biasanya di atas LITER, kadang ada merged cell)
                # Kita scan 5 baris ke atas dari baris LITER untuk mencari nama unit
                row_equip_idx = idx - 1 
                for i in range(idx - 1, max(-1, idx - 5), -1):
                    row_content = df_full.iloc[i].astype(str).str.upper()
                    # Indikator baris nama unit: ada kata TRAILER, TRUCK, atau kode L-
                    if row_content.str.contains('TRAILER').any() or row_content.str.contains('TRUCK').any() or row_content.str.contains(r'L\s*\d+').any():
                        row_equip_idx = i
                        break
                
                # Ambil baris Nama Unit dan lakukan Forward Fill (untuk merged cells)
                row_eq = df_full.iloc[row_equip_idx].ffill()
                
                # Ambil data (baris-baris di bawah LITER)
                data_rows = df_full.iloc[idx+1:]
                
                # Loop setiap kolom
                for col in range(df_full.shape[1]):
                    # Jika header kolom ini adalah 'LITER'
                    if str(df_full.iloc[idx, col]).strip().upper() == 'LITER':
                        # Ambil nama unit dari baris Equip
                        raw_equip = str(row_eq.iloc[col]).strip().upper()
                        
                        if "TOTAL" in raw_equip or "NAN" in raw_equip: continue
                        
                        # --- LOGIKA MAPPING: SAMA SEPERTI AGREGAT ---
                        # 1. Ekstrak potensi kode lambung (misal dari "TRAILER HINO (L 8038 US)")
                        lambung_candidate = extract_lambung_code(raw_equip)
                        
                        u_clean = ""
                        # Cek 1: Apakah kandidat lambung ada di map?
                        if lambung_candidate in lambung_to_unit_map:
                            u_clean = clean_unit_name(lambung_to_unit_map[lambung_candidate])
                        # Cek 2: Apakah nama raw ada di map?
                        elif raw_equip in lambung_to_unit_map:
                            u_clean = clean_unit_name(lambung_to_unit_map[raw_equip])
                        # Cek 3: Bersihkan kandidat lambung langsung
                        else:
                            u_clean = clean_unit_name(lambung_candidate)
                        
                        # --- FILTER FINAL: WHITELIST ---
                        # Apakah unit ini ada di daftar unit yang SUKSES dianalisa secara total?
                        if u_clean in VALID_UNIT_IDS:
                            val = pd.to_numeric(data_rows.iloc[:, col], errors='coerce').sum()
                            if val > 0:
                                monthly_data.append({'Unit_Clean': u_clean, 'Bulan': bulan_lbl, 'LITER': val})

except Exception as e: print(f"   [Warning] Gagal baca BBM Monthly: {e}")

df_bbm_monthly = pd.DataFrame(monthly_data)
if df_bbm_monthly.empty: 
    df_bbm_monthly = pd.DataFrame(columns=['Unit_Clean', 'Bulan', 'LITER'])
    print("   [WARNING] Data BBM Bulanan Kosong! Cek kembali nama sheet/header.")
else: 
    # Agregasi jika ada duplikat (jarang terjadi tapi aman)
    df_bbm_monthly = df_bbm_monthly.groupby(['Unit_Clean', 'Bulan']).sum().reset_index()

# --- B. DOORING BULANAN (FILTER UNIT VALID) ---
try:
    if 'BULAN' in df_dooring.columns:
        df_dooring['Bulan_Std'] = df_dooring['BULAN'].astype(str).str.upper().str.strip().map({
            'OKTOBER': 'Oktober', 'NOVEMBER': 'November'
        })
        # Filter: Hanya Unit Valid & Bulan Valid
        df_door_m = df_dooring[
            (df_dooring['Unit_Clean'].isin(VALID_UNIT_IDS)) & 
            (df_dooring['Bulan_Std'].notna())
        ]
        
        df_door_monthly = df_door_m.groupby(['Unit_Clean', 'Bulan_Std']).agg({
            'Ton_Dooring': 'sum', 'TonKm_Dooring': 'sum', 'Jarak_PP_Km': 'sum'
        }).reset_index().rename(columns={'Bulan_Std': 'Bulan', 'Jarak_PP_Km': 'Km_Dooring'})
    else: df_door_monthly = pd.DataFrame()
except: df_door_monthly = pd.DataFrame()

# --- C. HAULAGE BULANAN (FILTER UNIT VALID) ---
try:
    if 'TANGGAL' in df_haulage.columns:
        df_haulage['Bulan_Std'] = df_haulage['TANGGAL'].dt.month.map({10: 'Oktober', 11: 'November'})
        # Filter: Hanya Unit Valid
        df_haul_m = df_haulage[df_haulage['Unit_Clean'].isin(VALID_UNIT_IDS)]
        
        df_haul_monthly = df_haul_m.groupby(['Unit_Clean', 'Bulan_Std']).agg({
            'Berat_Ton': 'sum', 'TonKm': 'sum', 'Jarak_Km': 'sum'
        }).reset_index().rename(columns={
            'Bulan_Std': 'Bulan', 'Jarak_Km': 'Km_Haulage', 
            'Berat_Ton': 'Ton_Haulage', 'TonKm': 'TonKm_Haulage'
        })
    else: df_haul_monthly = pd.DataFrame()
except: df_haul_monthly = pd.DataFrame()

# --- D. MERGE DATA BULANAN ---
# Inisialisasi
if df_door_monthly.empty: df_door_monthly = pd.DataFrame(columns=['Unit_Clean', 'Bulan'])
if df_haul_monthly.empty: df_haul_monthly = pd.DataFrame(columns=['Unit_Clean', 'Bulan'])

# Merge (Outer Join untuk menangkap semua kemungkinan, lalu filter lagi)
df_monthly_final = pd.merge(df_bbm_monthly, df_door_monthly, on=['Unit_Clean', 'Bulan'], how='outer').fillna(0)
df_monthly_final = pd.merge(df_monthly_final, df_haul_monthly, on=['Unit_Clean', 'Bulan'], how='outer').fillna(0)

# Filter Akhir: Pastikan hanya unit yang ada di Whitelist
df_monthly_final = df_monthly_final[df_monthly_final['Unit_Clean'].isin(VALID_UNIT_IDS)]

# Restore Nama Asli
df_monthly_final['Nama_Unit'] = df_monthly_final['Unit_Clean'].map(clean_to_orig).fillna(df_monthly_final['Unit_Clean'])

# Pastikan semua kolom ada
for c in ['Ton_Haulage', 'Ton_Dooring', 'TonKm_Haulage', 'TonKm_Dooring', 'Km_Haulage', 'Km_Dooring', 'LITER']:
    if c not in df_monthly_final.columns: df_monthly_final[c] = 0

# Hitung Total
df_monthly_final['Total_Ton'] = df_monthly_final['Ton_Haulage'] + df_monthly_final['Ton_Dooring']
df_monthly_final['Total_TonKm'] = df_monthly_final['TonKm_Haulage'] + df_monthly_final['TonKm_Dooring']
df_monthly_final['Total_Km'] = df_monthly_final['Km_Haulage'] + df_monthly_final['Km_Dooring']
df_monthly_final['Fuel_Ratio'] = np.where(df_monthly_final['Total_TonKm'] > 0, 
                                          df_monthly_final['LITER'] / df_monthly_final['Total_TonKm'], 0)

cols_out = ['Nama_Unit', 'Bulan', 'LITER', 'Total_Ton', 'Total_TonKm', 'Fuel_Ratio', 'Total_Km']
df_monthly_out = df_monthly_final[cols_out].sort_values(['Nama_Unit', 'Bulan'])

# --- E. PIVOT TREN ---
df_pivot = df_monthly_out.pivot_table(index='Nama_Unit', columns='Bulan', values='Fuel_Ratio').reset_index().fillna(0)
if 'Oktober' in df_pivot.columns and 'November' in df_pivot.columns:
    df_pivot['Status_Tren'] = df_pivot.apply(lambda x: 
        "MEMBAIK (Irit)" if x['November'] > 0 and x['November'] < x['Oktober'] else
        ("MEMBURUK (Boros)" if x['November'] > x['Oktober'] and x['Oktober'] > 0 else 
        ("STABIL" if x['November'] == x['Oktober'] else "DATA TIDAK LENGKAP")), axis=1)
else:
    df_pivot['Status_Tren'] = "-"

# ==============================================================================
# 6. EXPORT EXCEL
# ==============================================================================
with pd.ExcelWriter(OUTPUT_FILE) as writer:
    df_sukses[cols_main].to_excel(writer, sheet_name='HASIL_ANALISA', index=False)
    df_monthly_out.to_excel(writer, sheet_name='Data_Bulanan', index=False)
    df_pivot.to_excel(writer, sheet_name='Laporan_Tren', index=False)
    df_no_bbm[cols_audit].to_excel(writer, sheet_name='OPS_TANPA_BBM', index=False)
    df_idle[cols_idle].to_excel(writer, sheet_name='BBM_TANPA_OPS', index=False)
    df_unmapped.to_excel(writer, sheet_name='GAGAL_MAPPING', index=False)

print(f"\nSELESAI! File audit disimpan di: {OUTPUT_FILE}")
print(f"1. Sukses Analisa : {len(df_sukses)} Unit")
print(f"2. Data Bulanan   : {len(df_monthly_out)} Baris Data (Unit Valid)")
print(f"3. Ops Tanpa BBM  : {len(df_no_bbm)} Unit")
print(f"4. BBM Tanpa Ops  : {len(df_idle)} Unit")
print(f"5. Gagal Mapping  : {len(df_unmapped)} Kode")
# Out:
# 4. Menyusun Laporan Audit & Tren Bulanan...
#    -> Whitelist Unit Valid: 55 Unit (Akan dicari di sheet bulanan)
#    -> Menghitung Tren Efisiensi Bulanan...
#
# SELESAI! File audit disimpan di: HASIL_ANALISA_TRUCKING_AUDIT.xlsx
# 1. Sukses Analisa : 55 Unit
# 2. Data Bulanan   : 110 Baris Data (Unit Valid)
# 3. Ops Tanpa BBM  : 1 Unit
# 4. BBM Tanpa Ops  : 145 Unit
# 5. Gagal Mapping  : 0 Kode

# %%
print("=== RINGKASAN VALIDASI NOMOR LAMBUNG ===\n")

# 1. Kumpulkan semua Nomor Lambung dari Dooring & Haulage
lambung_dooring = set(df_dooring['LAMBUNG'].dropna().astype(str).str.upper().str.strip().unique()) if 'LAMBUNG' in df_dooring.columns else set()
lambung_haulage = set(df_haulage['NO LAMBUNG'].dropna().astype(str).str.upper().str.strip().unique()) if 'NO LAMBUNG' in df_haulage.columns else set()

total_lambung_ops = lambung_dooring.union(lambung_haulage)
# Hapus string kosong jika ada
total_lambung_ops = {x for x in total_lambung_ops if x != "" and x != "NAN"}

print(f"Total Unit Unik di Operasional (Dooring/Haulage): {len(total_lambung_ops)} Unit")

# 2. Cek mana yang TIDAK ADA di BBM (Gagal Mapping)
# lambung_to_unit_map adalah kamus yang kita buat dari file BBM sebelumnya
lambung_hilang = [x for x in total_lambung_ops if x not in lambung_to_unit_map]

print(f"Total Unit Terdaftar di BBM: {len(total_lambung_ops) - len(lambung_hilang)} Unit")
print(f"Total Unit TIDAK DIKENALI (Gagal Mapping): {len(lambung_hilang)} Unit")

print("-" * 40)

if len(lambung_hilang) == 0:
    print("✅ STATUS: PERFECT MATCH!")
    print("Semua nomor lambung di Dooring/Haulage berhasil ditemukan di file BBM.")
else:
    print("❌ STATUS: ADA DATA YANG HILANG")
    print("Nomor Lambung berikut ada di kegiatan trucking, tapi TIDAK ADA di file BBM AAB:")
    print(lambung_hilang)
    print("\nSolusi: Cek sheet 'GAGAL_MAPPING' di file Excel output untuk detailnya.")
    
# 3. Cek Unit yang Terdaftar tapi LITER-nya 0 atau Tidak Ada Record Pengisian
# Ambil unit yang sukses di-mapping
unit_valid_ops = [lambung_to_unit_map[x] for x in total_lambung_ops if x in lambung_to_unit_map]
# Cek apakah unit tersebut punya data liter di df_bbm_total
unit_tanpa_bbm = [u for u in unit_valid_ops if u not in df_bbm_total['EQUIP NAME'].values]

if len(unit_tanpa_bbm) > 0:
    print(f"\n⚠️ PERHATIAN: Ada {len(unit_tanpa_bbm)} unit yang terdaftar (Mapping Sukses), tapi TIDAK ADA DATA PENGISIAN BBM (Liter 0/Kosong).")
    print("5 Unit Tanpa BBM :", unit_tanpa_bbm[:5])
    print("Cek sheet 'OPS_TANPA_BBM' di file Excel output.")
# Out:
# === RINGKASAN VALIDASI NOMOR LAMBUNG ===
#
# Total Unit Unik di Operasional (Dooring/Haulage): 56 Unit
# Total Unit Terdaftar di BBM: 56 Unit
# Total Unit TIDAK DIKENALI (Gagal Mapping): 0 Unit
# ----------------------------------------
# ✅ STATUS: PERFECT MATCH!
# Semua nomor lambung di Dooring/Haulage berhasil ditemukan di file BBM.
#
# ⚠️ PERHATIAN: Ada 1 unit yang terdaftar (Mapping Sukses), tapi TIDAK ADA DATA PENGISIAN BBM (Liter 0/Kosong).
# 5 Unit Tanpa BBM: ['L 8577 UK (EX.L 9561 UQ)']
# Cek sheet 'OPS_TANPA_BBM' di file Excel output.
